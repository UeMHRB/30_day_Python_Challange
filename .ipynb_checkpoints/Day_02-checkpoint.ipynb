# %% [markdown]
# # 🐍 Day 2: Variables & Built-in Functions
#
# Welcome to **Day 2** of your 30-Day Python Challenge! Today, you'll learn how to store data in **variables**, dynamically change data types using **type casting**, utilize Python's powerful **built-in functions**, and capture real-time input from users.
#
# ---
#
# <div style="
#   background: linear-gradient(135deg, #0f2027, #203a43, #2c5364);
#   color: #ffffff;
#   padding: 18px 24px;
#   border-radius: 10px;
#   border-left: 6px solid #38ef7d;
#   box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
#   margin-bottom: 20px;
# ">
#   <h3 style="color: #38ef7d; margin-top: 0; margin-bottom: 8px; font-size: 18px;">
#     🎯 Day 2 Focus Areas
#   </h3>
#   <p style="margin: 0; font-size: 14px; opacity: 0.95; line-height: 1.5;">
#     Moving beyond static scripts into dynamic, interactive Python programming!
#   </p>
# </div>
#
# ### 📚 Learning Objectives
#
# * **Variables & Naming Rules:** Understand variable creation, assignment, and standard `snake_case` conventions.
# * **Built-in Functions:** Master common functions like `len()`, `type()`, `str()`, `int()`, `float()`, `min()`, `max()`, and `sum()`.
# * **Type Casting:** Learn how to safely convert data between different types.
# * **User Interactivity:** Capture and handle user input dynamically using `input()`.
#
# ---
#
# ### 💡 Quick Reference
# 📖 *Reference:* Check out the official [Day 2 Curriculum on GitHub](https://github.com/Asabeneh/30-Days-Of-Python/blob/master/02_Day_Variables_builtin_functions/02_variables_builtin_functions.md) for extra reading.

# %% [markdown]
# # Exercises - Day 2

# %% [markdown]
# ---
#
# ### Exercise: Level 1
#
# 01. Declare a first name variable and assign a value to it
# 02. Declare a last name variable and assign a value to it
# 03. Declare a full name variable and assign a value to it
# 04. Declare a country variable and assign a value to it
# 05. Declare a city variable and assign a value to it
# 06. Declare an age variable and assign a value to it
# 07. Declare a year variable and assign a value to it
# 08. Declare a variable is_married and assign a value to it
# 09. Declare a variable is_true and assign a value to it
# 10. Declare a variable is_light_on and assign a value to it
# 11. Declare multiple variable on one line

# %%
first_name = "Muhammad"
last_name = "Hamza"
full_name = first_name + last_name
country,city = "Pakistan", "Lahore"
age = 23
year = 2026
is_married = False
is_true = True
is_light_on = True

# %% [markdown]
# ---
#
# ### Exercises: Level 2
#
# 1. Check the data type of all your variables using type() built-in function
# 2. Using the len() built-in function, find the length of your first name
# 3. Compare the length of your first name and your last name
# 4. Declare 5 as num_one and 4 as num_two
# 5. Add num_one and num_two and assign the value to a variable total
# 6. Subtract num_two from num_one and assign the value to a variable diff
# 7. Multiply num_two and num_one and assign the value to a variable product
# 8. Divide num_one by num_two and assign the value to a variable division
# 9. Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
# 10. Calculate num_one to the power of num_two and assign the value to a variable exp
# 11. Find floor division of num_one by num_two and assign the value to a variable floor_division
# 12. The radius of a circle is 30 meters.
# 13. Calculate the area of a circle and assign the value to a variable name of area_of_circle
# 14. Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# 15. Take radius as user input and calculate the area.
# 16. Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
# 17. Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords

# %%
variables = (first_name, last_name, full_name, country, city, age, year, is_married, is_true, is_light_on)

for i in range(len(variables)):
    print(f"{variables[i]}: {type(variables[i])}")
# Out:
# Muhammad: <class 'str'>
# Hamza: <class 'str'>
# MuhammadHamza: <class 'str'>
# Pakistan: <class 'str'>
# Lahore: <class 'str'>
# 23: <class 'int'>
# 2026: <class 'int'>
# False: <class 'bool'>
# True: <class 'bool'>
# True: <class 'bool'>

# %%
# Using the len() built-in function, find the length of your first name
# Compare the length of your first name and your last name

print(f"first_name length: ",len(first_name))
print(f"last_name length: ",len(last_name))

if len(first_name) > len(last_name):
    print("First name's length is more than last_name.")
# Out:
# first_name length:  8
# last_name length:  5
# First name's length is more than last_name.

# %%
# Declare 5 as num_one and 4 as num_two
# Add num_one and num_two and assign the value to a variable total
# Subtract num_two from num_one and assign the value to a variable diff
# Multiply num_two and num_one and assign the value to a variable product
# Divide num_one by num_two and assign the value to a variable division
# Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
# Calculate num_one to the power of num_two and assign the value to a variable exp
# Find floor division of num_one by num_two and assign the value to a variable floor_division

num_one, num_two = 5,4
print(f"num_one: {num_one} \nnum_two: {num_two}")

total = sum([num_one, num_two])
print("Sum:",total)

variable_diff = num_one - num_two
print("Difference:", variable_diff)

product = num_one * num_two
print(f"Product: {product}")

division = num_one / num_two
print("Division:", division)

remainder = num_two % num_one
print("Remainder:", remainder)

exp = num_one  ** num_two
print("Exp:", exp)

floor_division = num_one // num_two
print("Floor_Division:",floor_division)
# Out:
# num_one: 5
# num_two: 4
# Sum: 9
# Difference: 1
# Product: 20
# Division: 1.25
# Remainder: 4
# Exp: 625
# Floor_Division: 1

# %%
# The radius of a circle is 30 meters.
# Calculate the area of a circle and assign the value to a variable name of area_of_circle
# Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle

radius = 30
circle_area = 3.1416 * radius**2
circumference = 2 * 3.1416 * radius

vars = {"Radius": radius , "Circle_area":circle_area,  "Circumference":circumference}

for name,value in vars.items():
    print(f"{name}: {value}")
# Out:
# Radius: 30
# Circle_area: 2827.44
# Circumference: 188.496

# %%
# Take radius as user input and calculate the area.

radius = float(input("Enter radius of circle: "))
print(f"Area of circle is:", 3.1416 * radius **2)
# Out:
# Enter radius of circle:  5
# Area of circle is: 78.53999999999999

# %%
# Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
name,country,age = input("Enter name,country and age:").split(",")
print(name,country,age)
# Out:
# Enter name,country and age: Alice,USA,25
# Alice USA 25

# %%
# Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ---
#
# <div style="
#   background: linear-gradient(135deg, #11998e, #38ef7d);
#   color: white;
#   padding: 24px 30px;
#   border-radius: 12px;
#   text-align: center;
#   box-shadow: 0 4px 15px rgba(0, 0, 0, 0.15);
#   font-family: Arial, sans-serif;
#   margin: 25px 0;
# ">
#   <h2 style="margin: 0; padding: 0; color: white; border: none; font-size: 26px;">
#     🎉 Day 2 Completed!
#   </h2>
#   <p style="margin: 8px 0 0 0; font-size: 15px; opacity: 0.95;">
#     Awesome work! I have successfully mastered <b>Variables, Built-in Functions & User Input</b>.
#   </p>
#   <div style="margin-top: 15px;">
#     <span style="
#       background-color: rgba(255, 255, 255, 0.25);
#       padding: 6px 14px;
#       border-radius: 20px;
#       font-size: 13px;
#       font-weight: bold;
#       letter-spacing: 0.5px;
#     ">
#       🚀 2 / 30 Days Done • Keeping Up The Momentum!
#     </span>
#   </div>
# </div>
